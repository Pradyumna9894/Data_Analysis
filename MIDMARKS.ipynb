# %% [markdown]
# # CASE STUDY ON MIDMARKS
# # M.PRADYUMNA
# # 2211CS010351
# # GROUP-4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel('MIDMARKS.xlsx')
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data.head()
# Out:
#    S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0   1.0   ALPHA  12    0  17    9  19   15
# 1   2.0   ALPHA  19   12  16   16  18    3
# 2   3.0   ALPHA  18   14  18   18  18   16
# 3   4.0   ALPHA  15    9  19   17  19   15
# 4   5.0   ALPHA  18   17  19   19  20   18

# %% [markdown]
# Displays the first five rows of data

# %%
data.tail()
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19

# %% [markdown]
# It shows the last five rows of data

# %%
data['SECTION'] = data['SECTION'].fillna('SIGMA') 
data['SECTION'] = data['SECTION'].replace('', 'SIGMA')
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0     1.0   ALPHA  12    0  17    9  19   15
# 1     2.0   ALPHA  19   12  16   16  18    3
# 2     3.0   ALPHA  18   14  18   18  18   16
# 3     4.0   ALPHA  15    9  19   17  19   15
# 4     5.0   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   NaN    ZETA  19    8   8   19  17   18
# 714   NaN    ZETA  12    1   7   10  20    8
# 715   NaN    ZETA  17    6  14   14  17   18
# 716   NaN    ZETA  12    1   6    7  15   12
# 717   NaN    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data['S.NO'] = range(1, len(data) + 1)
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [718 rows x 8 columns]

# %%
data['FL'] = data['FL'].fillna(0) 
data=data.dropna()
data
# Out:
#      S.NO SECTION  DV M-II  PP BEEE  FL FIMS
# 0       1   ALPHA  12    0  17    9  19   15
# 1       2   ALPHA  19   12  16   16  18    3
# 2       3   ALPHA  18   14  18   18  18   16
# 3       4   ALPHA  15    9  19   17  19   15
# 4       5   ALPHA  18   17  19   19  20   18
# ..    ...     ...  ..  ...  ..  ...  ..  ...
# 713   714    ZETA  19    8   8   19  17   18
# 714   715    ZETA  12    1   7   10  20    8
# 715   716    ZETA  17    6  14   14  17   18
# 716   717    ZETA  12    1   6    7  15   12
# 717   718    ZETA  19   14  17   16  20   19
#
# [716 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 716 entries, 0 to 717
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S.NO     716 non-null    int64
#  1   SECTION  716 non-null    object
#  2   DV       716 non-null    object
#  3   M-II     716 non-null    object
#  4   PP       716 non-null    object
#  5   BEEE     716 non-null    object
#  6   FL       716 non-null    object
#  7   FIMS     716 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 50.3+ KB

# %%
subject_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
descriptive_stats_subjects = data['DV'].describe()
descriptive_stats_subjects
# Out:
# count     716
# unique     22
# top        20
# freq      103
# Name: DV, dtype: int64

# %%
descriptive_stats_subjects = data['PP'].describe()
descriptive_stats_subjects
# Out:
# count     716
# unique     24
# top        20
# freq      106
# Name: PP, dtype: int64

# %% [markdown]
# Above shows the different types of values present in the subjects DV and PP where it tells the total count and unique values in each column

# %%
data['DV'] = data['DV'].apply(pd.to_numeric, errors='coerce')
descriptive_stats_subjects_numeric = data['DV'].describe()
descriptive_stats_subjects_numeric
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\2269071650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DV'] = data['DV'].apply(pd.to_numeric, errors='coerce')
# count    705.000000
# mean      15.018440
# std        4.211517
# min        1.000000
# 25%       12.000000
# 50%       16.000000
# 75%       18.000000
# max       20.000000
# Name: DV, dtype: float64

# %% [markdown]
# This shows that the mean value of subject DV is 15.0184 while min,max,25%,50%,75% are 1.0,20.0,12.0,16.0,18.0 repectively

# %%
data['PP'] = data['PP'].apply(pd.to_numeric, errors='coerce')
descriptive_stats_subjects_numeric = data['PP'].describe()
descriptive_stats_subjects_numeric
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\1656460367.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PP'] = data['PP'].apply(pd.to_numeric, errors='coerce')
# count    701.000000
# mean      13.042796
# std        5.567600
# min        0.000000
# 25%        9.000000
# 50%       14.000000
# 75%       18.000000
# max       20.000000
# Name: PP, dtype: float64

# %% [markdown]
# Show cases the mean,min and max values of PP subject

# %%
columns_to_convert = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
for column in columns_to_convert:
    data[column] = pd.to_numeric(data[column], errors='coerce').fillna(0)
data
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\1673388919.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[column] = pd.to_numeric(data[column], errors='coerce').fillna(0)
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0
# ..    ...     ...   ...   ...   ...   ...   ...   ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0
# ...

# %% [markdown]
# Filling null values in the above data

# %%
subject_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
data[subject_columns] = data[subject_columns].apply(pd.to_numeric, errors='coerce')
data[subject_columns] = data[subject_columns].fillna(0)
data['TOTAL'] = data[subject_columns].sum(axis=1)
data
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\794154179.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[subject_columns] = data[subject_columns].apply(pd.to_numeric, errors='coerce')
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\794154179.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[subject_columns] = data[subject_columns].fillna(0)
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\794154179.py:4: SettingWithCopyWarning:
# ...

# %% [markdown]
# Adding another column called TOTAL

# %%
data['PERCENTAGE'] = (data['TOTAL'] /120)*100
print(data)
# Out:
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# 713   714    ZETA  19.0   8.0   8.0  19.0  17.0  18.0   89.0   74.166667
# 714   715    ZETA  12.0   1.0   7.0  10.0  20.0   8.0   58.0   48.333333
# 715   716    ZETA  17.0   6.0  14.0  14.0  17.0  18.0   86.0   71.666667
# 716   717    ZETA  12.0   1.0   6.0   7.0  15.0  12.0   53.0   44.166667
# 717   718    ZETA  19.0  14.0  17.0  16.0  20.0  19.0  105.0   87.500000
#
# [716 rows x 10 columns]
# ...

# %% [markdown]
# Adding a column called percentage

# %%
def assign_grade(percentage):
    if percentage >= 90:
        return 'A'
    elif percentage >= 80:
        return 'B'
    elif percentage >= 70:
        return 'C'
    elif percentage >= 60:
        return 'D'
    else:
        return 'F'
data['GRADE'] = data['PERCENTAGE'].apply(assign_grade)
data
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\2939107086.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['GRADE'] = data['PERCENTAGE'].apply(assign_grade)
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE GRADE
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000     D
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000     C
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000     B
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333     C
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000     A
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...   ...
# ...

# %% [markdown]
# Finding out the Grades of students

# %%
passing_marks = 10
subject_columns = ["DV", "M-II", "PP", "BEEE", "FL", "FIMS"]
data['Backlogs'] = (data[subject_columns] < passing_marks).sum(axis=1)
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\720493930.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Backlogs'] = (data[subject_columns] < passing_marks).sum(axis=1)

# %%
def assign_grade(PP):
    if PP >=18 :
        return "VERY GOOD"
        
    elif PP >=15 :
        return 'GOOD'
    elif PP >= 13:
        return 'AVERAGE'
    else:
        return 'POOR'
data['PP-skills'] = data['PP'].apply(assign_grade)
data
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\1518026464.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['PP-skills'] = data['PP'].apply(assign_grade)
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# ...

# %% [markdown]
# Finding out the programming skills of students based on their performance in PP subject

# %%
def assign_grade(DV):
    if DV >=18 :
        return "VERY GOOD"
        
    elif DV >=15 :
        return 'GOOD'
    elif DV >= 13:
        return 'AVERAGE'
    else:
        return 'POOR'
data['DV-skills'] = data['PP'].apply(assign_grade)
data
# Out:
# C:\Users\prady\AppData\Local\Temp\ipykernel_19264\4098484410.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['DV-skills'] = data['PP'].apply(assign_grade)
#      S.NO SECTION    DV  M-II    PP  BEEE    FL  FIMS  TOTAL  PERCENTAGE  \
# 0       1   ALPHA  12.0   0.0  17.0   9.0  19.0  15.0   72.0   60.000000
# 1       2   ALPHA  19.0  12.0  16.0  16.0  18.0   3.0   84.0   70.000000
# 2       3   ALPHA  18.0  14.0  18.0  18.0  18.0  16.0  102.0   85.000000
# 3       4   ALPHA  15.0   9.0  19.0  17.0  19.0  15.0   94.0   78.333333
# 4       5   ALPHA  18.0  17.0  19.0  19.0  20.0  18.0  111.0   92.500000
# ..    ...     ...   ...   ...   ...   ...   ...   ...    ...         ...
# ...

# %%
backlog_counts = data['Backlogs'].value_counts().sort_index()
plt.figure(figsize=(5, 5))
plt.pie(backlog_counts, labels=backlog_counts.index, autopct='%1.1f%%',colors=plt.cm.Paired.colors)
plt.title("Distribution of Backlogs Among Students")
plt.show()

# %%
data["PP-skills"].value_counts().plot( kind="pie", autopct="%1.1f%%", colors=sns.color_palette("Set2"), figsize=(5, 5))
plt.title("Programming Skills")
plt.ylabel("")  
plt.show()

# %%
dv_bins = [0, 13, 15,17,20]  
dv_labels = ["Very good", "Good", "Average","Poor"]
data['DV-skills'] = pd.cut(data["DV"], bins=programming_bins, labels=programming_labels, right=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 dv_bins = [0, 13, 15,17,20]
#       2 dv_labels = ["Very good", "Good", "Average","Poor"]
# ----> 3 data['DV-skills'] = pd.cut(data["DV"], bins=programming_bins, labels=programming_labels, right=False)
#
# NameError: name 'programming_bins' is not defined

# %%
dv_distribution = data['DV-skills'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(dv_distribution, labels=dv_distribution.index, autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title("DV Skills Distribution")
plt.show()

# %%
subset = data[['DV','M-II','PP','BEEE','FL','FIMS']]
print(subset)

# %% [markdown]
# Creating a subset from all the subjects to find out the number of toppers

# %%
subset.describe()

# %%
subset.value_counts()

# %%
data[data.PP<10]

# %% [markdown]
# This displays the number of students failed in PP subject

# %%
DV = data.SECTION[data.DV<10].value_counts()
DV

# %%
DV = data.SECTION[data.FL<10].value_counts()
DV

# %% [markdown]
# This displays the number of students failed from each section in the subject DV

# %%
BEEE = data.SECTION[data.BEEE<10].value_counts()
BEEE

# %% [markdown]
# This displays the number of backlogs from each section in BEEE section where  Delta section is at the top and Alpha section is at the bottom

# %%
data['BC']=(data[['DV','M-II','PP','BEEE','FL','FIMS']]<10).sum(axis=1)
data

# %% [markdown]
# Adding a column called BC which  abbreviates to "Backlogs"

# %%
sns.lineplot(x='SECTION', y='DV', data=data)
plt.show()

# %% [markdown]
# This shows the performance of students in DV subject

# %%
sns.lineplot(x='BC', y='SECTION', data=data)
plt.show()

# %% [markdown]
# This lineplot shows that Epsilon section is having the most number of backolgs followed by Gamma and Omega

# %%
sns.histplot(data['FL'], bins=6, kde=True)
plt.show()

# %% [markdown]
# The above histogram shows the scores of students in FL subject

# %%
plt.figure(figsize=(5, 5))
sns.histplot(data['BEEE'], bins=10,color='red')
plt.title('Distribution of Marks in BEEE', fontsize=16)
plt.xlabel('Marks in BEEE', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# Above shows the marks distribution of BEEE

# %%
subject_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']
subject_averages = data[subject_columns].mean()
subject_averages

# %% [markdown]
# This shows the average scores of each subject where FL is is having the highest score with 15.501 and M-II with lowest
# having 9.922

# %%
sns.barplot(data=data, x='SECTION', y='BC')

# %% [markdown]
# Above Bar Plot shows the mapping between Section and BC

# %%
subject_with_highest_avg = data[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean().idxmax()
plt.figure(figsize=(5, 5))
sns.histplot(data[subject_with_highest_avg], bins=10, color='orange')
plt.title(f'Distribution of Marks in {subject_with_highest_avg}', fontsize=16)
plt.xlabel(f'Marks in {subject_with_highest_avg}', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# This analysis shows that most of the students scored 20 in FL which made the subjects average too high which is 15.50

# %%
subject_with_highest_avg = data[['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']].mean().idxmin()
plt.figure(figsize=(5, 5))
sns.histplot(data[subject_with_highest_avg], bins=10, color='yellow')
plt.title(f'Distribution of Marks in {subject_with_highest_avg}', fontsize=16)
plt.xlabel(f'Marks in {subject_with_highest_avg}', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.show()

# %% [markdown]
# This shows the distribution of in M-II subject which is having the lowest average. This also tell us that singifiacnt amount of
# students scored 20 and on the other hand huge number of students scored 0 which  made the average go too low.

# %%
plt.scatter(data['FIMS'], data['BEEE'], color='YELLOW')
plt.title("Scatter Plot of FIMS vs BEEE")
plt.xlabel("FIMS Values")
plt.ylabel("BEEE Values")
plt.show()

# %% [markdown]
# Scatter plot shows correlation between FIMS and BEEE subjects

# %%
plt.scatter(data['M-II'], data['PP'], color='PURPLE')
plt.title("Scatter Plot of M-II vs PP")
plt.xlabel("M-II Values")
plt.ylabel("PP Values")
plt.show()

# %% [markdown]
# Scatter plot shows correlation between M-II and PP subjects

# %%
column_name = 'DV' 
category_counts = data['DV'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title(f"Distribution of {column_name}")
plt.show()

# %% [markdown]
# This piechart shows the share of percentage of students scoring their respective marks in DV subjects

# %%
column_name = 'FIMS' 
category_counts = data['FIMS'].value_counts()
plt.figure(figsize=(5, 5))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title(f"Distribution of {column_name}")
plt.show()

# %% [markdown]
# This shows the distibution in FIMS subject

# %%
plt.figure(figsize=[5, 5])
subject_averages.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired.colors)
plt.title("Subject-wise Average Scores")
plt.ylabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 2
#       1 plt.figure(figsize=[5, 5])
# ----> 2 subject_averages.plot(kind='pie', autopct='%1.1f%%', colors=plt.cm.Paired.colors)
#       3 plt.title("Subject-wise Average Scores")
#       4 plt.ylabel('')
#
# NameError: name 'subject_averages' is not defined

# %%
category_means = data.groupby('DV')['PP'].mean()  # Replace 'Category' and 'Value' with column names

plt.figure(figsize=(6, 6))
plt.plot(category_means.index, category_means.values, marker='o', linestyle='-', color='green')
plt.title("Category-Wise Average Values")
plt.xlabel("Category")
plt.ylabel("Average Value")
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# Line plot shows the comparision between DV and PP

# %%
category_means = data.groupby('M-II')['FIMS'].mean()  # Replace 'Category' and 'Value' with column names

plt.figure(figsize=(6, 6))
plt.plot(category_means.index, category_means.values, marker='o', linestyle='-', color='blue')
plt.title("Category-Wise Average Values")
plt.xlabel("Category")
plt.ylabel("Average Value")
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# Line plot shows the comparision between M-II and FIMS

# %%
score_columns = ['DV', 'M-II', 'PP', 'BEEE', 'FL', 'FIMS']

# Create a boxplot for the score columns
plt.figure(figsize=(6, 6))
data[score_columns].boxplot()

# Add titles and labels
plt.title("Box Plots of Scores")
plt.ylabel("Scores")
plt.xlabel("Subjects")
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# Box plot shows the scores of each subject where M-II is having lowest 25% percent value and where FL has the highest 75%
# value and it also coincides with its max value

# %%
for col in data.columns[2:]:
    data[col] = pd.to_numeric(data[col], errors='coerce')
passing_marks = 10
subject_section_pass = data.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] >= passing_marks).sum()
)
subject_section_fail = data.groupby('SECTION').apply(
    lambda df: (df.iloc[:, 2:] < passing_marks).sum()
)
total_students_per_section = data.groupby('SECTION').size()
prob_pass = subject_section_pass.div(total_students_per_section, axis=0)
prob_fail = subject_section_fail.div(total_students_per_section, axis=0)
print("Number of students passing each subject in each section:")
print(subject_section_pass)
print("\nNumber of students failing each subject in each section:")
print(subject_section_fail)
print("\nProbability of students passing each subject in each section:")
print(prob_pass)
print("\nProbability of students failing each subject in each section:")
print(prob_fail)
# Out:
# Number of students passing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    73    72  78    82  89    68
# BETA     73    65  82    49  89    79
# DELTA    76    45  62    44  89    86
# EPSILON  84    24  39    71  80    66
# GAMMA    79    44  54    73  88    67
# OMEGA    80    32  74    69  78    83
# SIGMA    82    60  74    65  86    79
# ZETA     82    27  40    72  75    70
#
# Number of students failing each subject in each section:
#          DV  M-II  PP  BEEE  FL  FIMS
# SECTION
# ALPHA    17    18  11     7   0    21
# BETA     17    25   7    40   1    11
# DELTA    12    43  27    44   0     2
# EPSILON   3    63  48    16   7    21
# GAMMA     8    43  33    14   0    19
# OMEGA     8    56  13    15   7     0
# SIGMA     4    26  11    20   0     5
# ZETA      7    61  48    16  14    17
#
# Probability of students passing each subject in each section:
#                DV      M-II        PP      BEEE        FL      FIMS
# ...

# %%
import scipy.stats as stats

# %%
t_statistic,p_value = stats.ttest_1samp(data[data['SECTION']=='ALPHA']['DV'],data.DV.mean())
print(t_statistic,p_value)
# Out:
# -3.0546455966439896 0.002972712305590382

# %%
t_statistic,p_value = stats.ttest_1samp(data[data['SECTION']=='ALPHA']['PP'],data.PP.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value = stats.ttest_1samp(data[data['SECTION']=='ALPHA']['FIMS'],data.FIMS.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value = stats.ttest_1samp(data[data['SECTION']=='ALPHA']['FL'],data.FL.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value = stats.ttest_1samp(data[data['SECTION']=='ALPHA']['FL'],data.FL.mean())
print(t_statistic,p_value)
# Out:
# nan nan

# %%
t_statistic,p_value = stats.ttest_1samp(data[data['SECTION']=='ALPHA']['FL'],data.FL.mean())
print(t_statistic,p_value)
